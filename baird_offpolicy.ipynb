# %% [markdown]
# ## Original Code from Suttonported to Python

# %%
import numpy as npimport matplotlib.pyplot as plt# feature matrixPhi=np.zeros((7,8))Phi[:,-1] = 1Phi[-1, -1] = 2Phi[:,:-1] += 2*np.diag(np.ones(7))Phi[-1, -2] = 1N,K = Phi.shape# Transition matrixT = np.zeros((7,7))T[:,-1] = 1#T[-1, -1] = 0.99gamma = 0.99#parameter used for TD, GTD2 and TDCalpha_td = .1;# GTD1 parameteralpha_gtd1 = .05 #;%.008;beta_gtd1 = alpha_gtd1 * 10 #;%20;eta_gtd1 = beta_gtd1 / alpha_gtd1;# GTD2 parameteralpha_gtd2=.05 #;%.03;beta_gtd2 = alpha_gtd2 * 10eta_gtd2 = beta_gtd2 / alpha_gtd2# TDCalpha_tdc = 0.05beta_tdc = alpha_tdc * 10 #;%%alpha*10; used in original GTD papereta_tdc = beta_tdc / alpha_tdc# Number of sweepsnsteps = 100methods = []param = np.zeros((K,nsteps))param_tdc = np.zeros((K,nsteps))param_gtd1 = np.zeros((K,nsteps))param_gtd2 = np.zeros((K,nsteps))# Initial values as is in Rich's booktheta_td = np.array([1., 1., 1., 1., 1., 1., 10., 1.])theta_tdc = theta_tdtheta_gtd2 = theta_tdtheta_gtd1 = theta_td# Initializationsw_tdc = np.zeros(K)w_gtd2 = np.zeros(K)w_gtd1 = np.zeros(K)rho_tdc_time = np.zeros((2*K,nsteps))rho_gtd2_time = np.zeros((2*K,nsteps))# concatenation of parametersrho_tdc = np.hstack((w_tdc, theta_tdc))rho_gtd2 = np.hstack((w_gtd2, theta_gtd2))rho_gtd1 = np.hstack((w_gtd1, theta_gtd1))D = np.eye(N) / N#D = np.diag([  0., 0.,0.,0.,0.,0.,1.00e+00])Phi = np.matrix(Phi)F = Phi.T * np.matrix(D) * (gamma*T) * PhiCmat = Phi.T * np.matrix(D) * PhiA = F - Cmatb = np.zeros(K) # indicates average reward= E[r*phi]inv_Cmat = np.linalg.pinv(Cmat)# TDC matrixG_tdc = np.zeros((K * 2, K * 2))G_tdc[:K, :K] = -eta_tdc * CmatG_tdc[:K, K:] = eta_tdc * AG_tdc[K:, :K] = -F.TG_tdc[K:, K:] = Ag_tdc = np.hstack((eta_tdc * b, b))# GTD2 matrixG_gtd2 = np.zeros((K * 2, K * 2))G_gtd2[:K, :K] = -eta_gtd2 * CmatG_gtd2[:K, K:] = eta_gtd2 * AG_gtd2[K:, :K] = -A.Tg_gtd2 = np.hstack((eta_gtd2 * b, np.zeros(K)))# GTD1 matrixG_gtd1 = np.zeros((K * 2, K * 2))G_gtd1[:K, :K] = -eta_gtd1 * np.eye(K)G_gtd1[:K, K:] = eta_gtd1 * AG_gtd1[K:, :K] = -A.Tg_gtd1 = np.hstack((eta_gtd1 * b, np.zeros(K)))for i in xrange(nsteps):    param[:,i] = theta_td    #TD(0) update    theta_td += np.array(alpha_td * (np.dot(A, theta_td) + b)).flatten()    param_tdc[:,i] = rho_tdc[K:]    #TDC update    rho_tdc += np.array(alpha_tdc * (np.dot(G_tdc , rho_tdc) + g_tdc)).flatten()    param_gtd2[:,i] = rho_gtd2[K:]    #GTD2 update    rho_gtd2 +=np.array(alpha_gtd2 * (np.dot(G_gtd2, rho_gtd2) + g_gtd2)).flatten()    param_gtd1[:,i] = rho_gtd1[K:]    #GTD1 update    rho_gtd1 +=np.array(alpha_gtd1 * (np.dot(G_gtd1, rho_gtd1) + g_gtd1)).flatten()

# %% [markdown]
# ### Plot according to Suttons Paper

# %%
def RMSPBE(p):    v = np.dot(A, p) + b    return float(np.sqrt(v * inv_Cmat * v.T))RMSPBE_TD = np.zeros(nsteps)RMSPBE_TDC = np.zeros(nsteps)RMSPBE_GTD2 = np.zeros(nsteps)RMSPBE_GTD1 = np.zeros(nsteps)for i in xrange(nsteps):    RMSPBE_TD[i] = RMSPBE(param[:,i])    RMSPBE_TDC[i] = RMSPBE(param_tdc[:,i])    RMSPBE_GTD1[i] = RMSPBE(param_gtd1[:,i])    RMSPBE_GTD2[i] = RMSPBE(param_gtd2[:,i])plt.figure(figsize=(12,10))#plt.plot(param[-1,:], label=r"$\theta_0$")plt.plot(RMSPBE_TD, label="TD(0)")plt.plot(RMSPBE_TDC, label="TDC")plt.plot(RMSPBE_GTD1, label="GTD1")plt.plot(RMSPBE_GTD2, label="GTD2")plt.legend()plt.xlabel("Sweeps")plt.xlim(0,30)plt.ylim(-2,20)plt.grid(b=True, axis='y')#plt.yscale("log")print "Final Errors:"print "TD(0) {:.4}".format(RMSPBE_TD[-1])print "TDC {:.4}".format(RMSPBE_TDC[-1])print "GTD1 {:.4}".format(RMSPBE_GTD1[-1])print "GTD2 {:.4}".format(RMSPBE_GTD2[-1])
# Out:
# Final Errors:TD(0) 93.62TDC 0.007379GTD1 0.008279GTD2 0.007378

# %% [markdown]
# # Own reimplementation

# %%
import tdimport examplesimport numpy as npimport matplotlib.pyplot as pltfrom task import LinearDiscreteValuePredictionTaskimport itertoolsnp.set_printoptions(precision=2, linewidth=120)def get_task(mu="target"):    n = 8    beh_pi = np.ones((n + 1, 2))    beh_pi[:, 0] = float(n) / (n + 1)    beh_pi[:, 1] = float(1) / (n + 1)    target_pi = np.zeros((n + 1, 2))    target_pi[:, 0] = 0    target_pi[:, 1] = 1    mdp = examples.BairdStarExample(n)    phi = mdp.phi    task = LinearDiscreteValuePredictionTask(mdp, 0.99, mdp.phi,                                        np.asarray(n * [1.] + [10., 1.]),                                       policy=beh_pi, target_policy=target_pi)    task.beh_mu = np.array([1./(n+1)]*(n+1))    if mu is "target":        task.mu = np.array([0.] * n + [1.])    elif mu is "uniform":        task.mu = task.beh_mu.copy()    return task
# Out:
# Warning: argument must be an int, or have a fileno() method.

# %% [markdown]
# ## Deterministic updates

# %%
import tddetmethods = []task = get_task("target")alpha = 0.1mu = 3m = td.TDC(alpha=alpha, beta=alpha*mu, gamma=task.gamma, phi=task.phi)m.name = r"TDC $\alpha$={} $\mu$={}".format(alpha, mu)        m.color = "blue"            detmethods.append(m)   alpha = 0.1mu = 3m = td.GTD2(alpha=alpha, beta=alpha*mu, gamma=task.gamma, phi=task.phi)m.name = r"GTD2 $\alpha$={} $\mu$={}".format(alpha, mu)        m.color = "green"            detmethods.append(m)   alpha = 0.002mu = 0.5m = td.GTD2(alpha=alpha, beta=alpha*mu, gamma=task.gamma, phi=task.phi)m.name = r"GTD2 $\alpha$={} $\mu$={}".format(alpha, mu)        m.color = "#8324FF"            detmethods.append(m)  alpha = 0.1mu = 6m = td.GTD(alpha=alpha, beta=alpha*mu, gamma=task.gamma, phi=task.phi)m.name = r"GTD $\alpha$={} $\mu$={}".format(alpha, mu)        m.color = "black"            detmethods.append(m)   alpha = 0.5m = td.LinearTDLambda(alpha=alpha, gamma=task.gamma, phi=task.phi, lam=0)m.name = r"TD(0) $\alpha$={}".format(alpha)    m.color = "red"                                detmethods.append(m)   err = task.deterministic_error_traces(detmethods, 40, criterion="RMSPBE")

# %%
plt.figure(figsize=(14,8))plt.ylabel(r"$\sqrt{MSPBE}$")plt.xlabel("Updates")    print "Final errors"for i, m in enumerate(detmethods):     plt.plot(range(err.shape[1]),err[i,:], label=m.name, color=m.color)    print m.name, err[i,-1]plt.yscale("log")plt.ylim(0,0.4)plt.legend(loc="upper right")
# Out:
# Final errorsTDC $\alpha$=0.1 $\mu$=3 0.0125875495993GTD2 $\alpha$=0.1 $\mu$=3 0.0119414543319GTD2 $\alpha$=0.002 $\mu$=0.5 0.11952822262GTD $\alpha$=0.1 $\mu$=6 0.0127724195095TD(0) $\alpha$=0.5 701.28470134

# %% [markdown]
# ## Stochastic updates

# %%
n_indep = 10n_iter = 4000methods = []task = get_task("uniform")for alpha, mu, color in [(0.0003,1000, "orange"), (0.0015 , 4, "#00AA00")]:    m = td.TDC(alpha=alpha, beta=mu*alpha, phi=task.phi)            m.name = r"TDC $\alpha$={} $\mu$={}".format(alpha, mu)            m.color = color                methods.append(m)   for alpha, mu, color in [(0.01, 2, "red"), (0.0012, 1, "k")]:    m = td.GTD(alpha=alpha, beta=mu*alpha, phi=task.phi)    m.name = r"GTD $\alpha$={} $\mu$={}".format(alpha, mu)          m.color = color     methods.append(m)for alpha, mu, color in [(0.01,2, "#5029A5")]:    m = td.GeriTDC(alpha=alpha, beta=mu*alpha, phi=task.phi)            m.name = r"Geri TDC $\alpha$={} $\mu$={}".format(alpha, mu)            m.color = color                methods.append(m)     for alpha, mu, color in [(0.003, 4, "cyan"), (0.001, 2, "#f000f0")]:        m = td.GTD2(alpha=alpha, beta=mu*alpha, phi=task.phi)           m.name = r"GTD2 $\alpha$={} $\mu$={}".format(alpha, mu)          m.color = color                methods.append(m)        for alpha, color in [(0.0001, "#0000ff")]:    m = td.LinearTDLambda(alpha=alpha, phi=task.phi, lam=0)    m.name = r"TD(0) $\alpha$={}".format(alpha)        m.color = color                                    methods.append(m)

# %%
mean, std, raw = task.avg_error_traces(methods, n_indep, n_samples=n_iter, criterion="RMSPBE", verbose=True)
# Out:
# 0 %   0 of 10 seeds | 0:00:00.000023 / est. -10
#  %   1 of 10 seeds | 0:00:04.061175 / est. 0:00:40.61175020
#  %   2 of 10 seeds | 0:00:08.180986 / est. 0:00:40.90493030
#  %   3 of 10 seeds | 0:00:12.148707 / est. 0:00:40.49569040
#  %   4 of 10 seeds | 0:00:16.061063 / est. 0:00:40.15265750
#  %   5 of 10 seeds | 0:00:20.453659 / est. 0:00:40.90731860
#  %   6 of 10 seeds | 0:00:24.549443 / est. 0:00:40.91573870
#  %   7 of 10 seeds | 0:00:29.181124 / est. 0:00:41.68732080
#  %   8 of 10 seeds | 0:00:33.091503 / est. 0:00:41.36437990
#  %   9 of 10 seeds | 0:00:37.256295 / est. 0:00:41.395883100
#  %   Total: 0:00:41.936317

# %%
plt.figure(figsize=(14,8))plt.ylabel(r"$\sqrt{MSPBE}$")plt.xlabel("Timesteps")    print "Final errors"for i, m in enumerate(methods):     plt.errorbar(range(mean.shape[1]),mean[i,:], yerr=std[i,:], errorevery=150, label=m.name, color=m.color)    print m.name, mean[i,-1]plt.yscale("log")plt.ylim(10**(-2.4),10**2)plt.xlim(0,4000)plt.legend(loc="upper right")
# Out:
# Final errorsTDC $\alpha$=0.0003 $\mu$=1000 0.455431038564TDC $\alpha$=0.0015 $\mu$=4 0.0622351954539GTD $\alpha$=0.01 $\mu$=2
#  0.0490721828074GTD $\alpha$=0.0012 $\mu$=1 0.639209950689Geri TDC $\alpha$=0.01 $\mu$=2 0.00422168838528GTD2 $\alpha$=0.003 $\mu$=4
#  0.0217947042485GTD2 $\alpha$=0.001 $\mu$=2 0.38820216691TD(0) $\alpha$=0.0001 9.91483375474

# %%
mean, std, raw = task.avg_error_traces(methods, n_indep, n_samples=n_iter, criterion="RMSPBE", verbose=True)
# Out:
# 0 %   0 of 10 seeds | 0:00:00.000013 / est. -10
#  %   1 of 10 seeds | 0:00:04.011798 / est. 0:00:40.11798020
#  %   2 of 10 seeds | 0:00:08.036004 / est. 0:00:40.18002030
#  %   3 of 10 seeds | 0:00:11.978787 / est. 0:00:39.92929040
#  %   4 of 10 seeds | 0:00:16.068873 / est. 0:00:40.17218250
#  %   5 of 10 seeds | 0:00:20.486694 / est. 0:00:40.97338860
#  %   6 of 10 seeds | 0:00:24.922567 / est. 0:00:41.53761270
#  %   7 of 10 seeds | 0:00:29.264329 / est. 0:00:41.80618480
#  %   8 of 10 seeds | 0:00:33.269015 / est. 0:00:41.58626990
#  %   9 of 10 seeds | 0:00:37.253579 / est. 0:00:41.392866100
#  %   Total: 0:00:41.176754

# %%
plt.figure(figsize=(18,12))plt.ylabel(r"$\sqrt{MSPBE}$")plt.xlabel("Timesteps")    print "Final errors"for i, m in enumerate(methods):     plt.errorbar(range(mean.shape[1]),mean[i,:], yerr=std[i,:], errorevery=100, label=m.name, color=m.color)    print m.name, mean[i,-1]plt.yscale("log")plt.ylim(0,10**3)plt.legend(loc="upper right")plt.title("MSPBE assuming uniform state distribution")
# Out:
# Final errorsTDC $\alpha$=0.0003 $\mu$=1000 0.455431038564TDC $\alpha$=0.0015 $\mu$=4
#  0.0622351954539GTD $\alpha$=0.01 $\mu$=2 0.0490721828074GTD $\alpha$=0.0012 $\mu$=1 0.639209950689Geri TDC $\alpha$=0.01 $\mu$=2
#  0.00422168838528GTD2 $\alpha$=0.003 $\mu$=4 0.0217947042485GTD2 $\alpha$=0.001 $\mu$=2 0.38820216691TD(0) $\alpha$=0.0001
#  9.91483375474
# /home/christoph/.virtualenvs/sci/local/lib/python2.7/site-packages/matplotlib/font_manager.py:1214: UserWarning: findfont: Font family ['serif'] not found. Falling back to Bitstream Vera Sans  (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Parameter Search### Evaluation function

# %%
from joblib import Parallel, delayedimport itertoolsfrom matplotlib.colors import LogNormdef plot_error_grid(val, alphas, mus, maxerr=5):    ferr = val.copy()    ferr[val > maxerr] = np.nan    plt.figure(figsize=(12,10))    plt.imshow(ferr, interpolation="nearest", cmap="hot", norm=LogNorm(vmin=np.nanmin(ferr), vmax=np.nanmax(ferr)))    plt.yticks(range(len(alphas)), alphas)    plt.xticks(range(len(mus)), mus, rotation=45, ha="right")    plt.xlabel(r"$\mu$")    plt.ylabel(r"$\alpha$")    plt.colorbar()

# %% [markdown]
# ### Uninformed grid search### GTD2

# %%
task = get_task("target")def run(alpha, mu, method_class=td.GTD2):    np.seterr(all="ignore")    m = method_class(alpha=alpha, beta=mu*alpha, phi=task.phi)    mean, std, raw = task.avg_error_traces([m], n_indep=3, n_samples=3000, criterion="RMSPBE", verbose=False)    val = np.mean(mean[0,-2000:])    #print "Evaluated alpha={}, mu={} to {}".format(alpha, mu, val)    return valgtd2alphas = np.power(10., np.linspace(-5, -1, 20))gtd2mus = np.power(2., np.linspace(-13, 10, 30))k = (delayed(run)(*x) for x in itertools.product(gtd2alphas, gtd2mus))res = Parallel(n_jobs=3, verbose=11)(k) gtd2err = np.array(res).reshape((len(gtd2alphas), len(gtd2mus)))
# Out:
# [Parallel(n_jobs=3)]: Done   1 out of 600 | elapsed:    4.1s remaining: 41.3min[Parallel(n_jobs=3)]: Done  52 out of 600 | elapsed:  1.2min remaining: 12.5min
# [Parallel(n_jobs=3)]: Done 107 out of 600 | elapsed:  2.6min remaining: 11.8min[Parallel(n_jobs=3)]: Done 162 out of 600 | elapsed:  3.8min remaining: 10.2min
# [Parallel(n_jobs=3)]: Done 217 out of 600 | elapsed:  5.1min remaining:  8.9min[Parallel(n_jobs=3)]: Done 272 out of 600 | elapsed:  6.3min remaining:  7.6min
# [Parallel(n_jobs=3)]: Done 327 out of 600 | elapsed:  7.6min remaining:  6.3min[Parallel(n_jobs=3)]: Done 382 out of 600 | elapsed:  8.8min remaining:  5.1min
# [Parallel(n_jobs=3)]: Done 437 out of 600 | elapsed: 10.1min remaining:  3.8min[Parallel(n_jobs=3)]: Done 492 out of 600 | elapsed: 11.2min remaining:  2.5min
# [Parallel(n_jobs=3)]: Done 547 out of 600 | elapsed: 12.5min remaining:  1.2min[Parallel(n_jobs=3)]: Done 600 out of 600 | elapsed: 13.8min finished

# %%
plot_error_grid(gtd2err, gtd2alphas, gtd2mus, maxerr=1)

# %%
task = get_task("uniform")def run(alpha, mu, method_class=td.GTD2):    np.seterr(all="ignore")    m = method_class(alpha=alpha, beta=mu*alpha, phi=task.phi)    mean, std, raw = task.avg_error_traces([m], n_indep=10, n_samples=3000, criterion="RMSPBE", verbose=False)    val = np.mean(mean[0,-2000:])    #print "Evaluated alpha={}, mu={} to {}".format(alpha, mu, val)    return valgtd2alphas = np.power(10., np.linspace(-5, -1, 20))gtd2mus = np.power(2., np.linspace(-13, 10, 30))k = (delayed(run)(*x) for x in itertools.product(gtd2alphas, gtd2mus))res = Parallel(n_jobs=4, verbose=11)(k) gtd2err = np.array(res).reshape((len(gtd2alphas), len(gtd2mus)))
# Out:
# [Parallel(n_jobs=4)]: Done   1 out of 600 | elapsed:   16.0s remaining: 159.7min[Parallel(n_jobs=4)]: Done  52 out of 600 | elapsed:  3.6min remaining: 38.2min
# [Parallel(n_jobs=4)]: Done 107 out of 600 | elapsed:  7.5min remaining: 34.8min[Parallel(n_jobs=4)]: Done 162 out of 600 | elapsed: 11.4min remaining: 31.0min
# [Parallel(n_jobs=4)]: Done 217 out of 600 | elapsed: 15.4min remaining: 27.2min[Parallel(n_jobs=4)]: Done 272 out of 600 | elapsed: 19.4min remaining: 23.3min
# [Parallel(n_jobs=4)]: Done 327 out of 600 | elapsed: 23.2min remaining: 19.4min[Parallel(n_jobs=4)]: Done 382 out of 600 | elapsed: 27.1min remaining: 15.5min
# [Parallel(n_jobs=4)]: Done 437 out of 600 | elapsed: 31.0min remaining: 11.6min[Parallel(n_jobs=4)]: Done 492 out of 600 | elapsed: 34.7min remaining:  7.6min
# [Parallel(n_jobs=4)]: Done 547 out of 600 | elapsed: 38.5min remaining:  3.7min[Parallel(n_jobs=4)]: Done 600 out of 600 | elapsed: 42.0min finished

# %%
plot_error_grid(gtd2err, gtd2alphas, gtd2mus, maxerr=20)

# %%
task = get_task("uniform")def run(alpha, mu, method_class=td.GTD2):    np.seterr(all="ignore")    m = method_class(alpha=alpha, beta=mu*alpha, phi=task.phi)    err = task.deterministic_error_traces([m], 100, criterion="RMSPBE")    val = np.mean(err)    #print "Evaluated alpha={}, mu={} to {}".format(alpha, mu, val)    return valalphas = np.power(10., np.linspace(-4, -0, 50))mus = np.power(2., np.linspace(-10, 15, 50))k = (delayed(run)(*x) for x in itertools.product(alphas, mus))res = Parallel(n_jobs=4, verbose=11)(k) err = np.array(res).reshape((len(alphas), len(mus)))
# Out:
# [Parallel(n_jobs=4)]: Done   1 out of 610 | elapsed:    0.1s remaining:   31.1s[Parallel(n_jobs=4)]: Done 222 out of 2500 | elapsed:    1.0s remaining:   10.0s
# [Parallel(n_jobs=4)]: Done 450 out of 2500 | elapsed:    2.0s remaining:    9.2s[Parallel(n_jobs=4)]: Done 678 out of 2500 | elapsed:    2.9s remaining:    7.8s
# [Parallel(n_jobs=4)]: Done 906 out of 2500 | elapsed:    3.9s remaining:    6.9s[Parallel(n_jobs=4)]: Done 1134 out of 2500 | elapsed:    4.8s remaining:    5.8s
# [Parallel(n_jobs=4)]: Done 1362 out of 2500 | elapsed:    5.8s remaining:    4.8s[Parallel(n_jobs=4)]: Done 1590 out of 2500 | elapsed:    6.7s remaining:    3.8s
# [Parallel(n_jobs=4)]: Done 1818 out of 2500 | elapsed:    7.7s remaining:    2.9s[Parallel(n_jobs=4)]: Done 2046 out of 2500 | elapsed:    8.7s remaining:    1.9s
# [Parallel(n_jobs=4)]: Done 2274 out of 2500 | elapsed:    9.8s remaining:    1.0s[Parallel(n_jobs=4)]: Done 2500 out of 2500 | elapsed:   10.7s finished

# %%
plot_error_grid(err, alphas, mus, maxerr=15)

# %% [markdown]
# ### TDC

# %%
task = get_task("target")def run(alpha, mu, method_class=td.TDC):    np.seterr(all="ignore")    m = method_class(alpha=alpha, beta=mu*alpha, phi=task.phi)    mean, std, raw = task.avg_error_traces([m], n_indep=3, n_samples=3000, criterion="RMSPBE", verbose=False)    val = np.mean(mean[0,-2000:])    #print "Evaluated alpha={}, mu={} to {}".format(alpha, mu, val)    return valalphas = np.power(10., np.linspace(-6, -1.5, 20))mus = np.power(2., np.linspace(-10, 15, 30))k = (delayed(run)(*x) for x in itertools.product(alphas, mus))res = Parallel(n_jobs=4, verbose=11)(k) err = np.array(res).reshape((len(alphas), len(mus)))
# Out:
# [Parallel(n_jobs=4)]: Done   1 out of 600 | elapsed:    4.3s remaining: 42.8min[Parallel(n_jobs=4)]: Done  52 out of 600 | elapsed:   47.5s remaining:  8.3min
# [Parallel(n_jobs=4)]: Done 107 out of 600 | elapsed:  1.6min remaining:  7.2min[Parallel(n_jobs=4)]: Done 162 out of 600 | elapsed:  2.4min remaining:  6.4min
# [Parallel(n_jobs=4)]: Done 217 out of 600 | elapsed:  3.3min remaining:  5.8min[Parallel(n_jobs=4)]: Done 272 out of 600 | elapsed:  4.2min remaining:  5.0min
# [Parallel(n_jobs=4)]: Done 327 out of 600 | elapsed:  4.9min remaining:  4.1min[Parallel(n_jobs=4)]: Done 382 out of 600 | elapsed:  5.7min remaining:  3.3min
# [Parallel(n_jobs=4)]: Done 437 out of 600 | elapsed:  6.5min remaining:  2.4min[Parallel(n_jobs=4)]: Done 492 out of 600 | elapsed:  7.3min remaining:  1.6min
# [Parallel(n_jobs=4)]: Done 547 out of 600 | elapsed:  8.1min remaining:   47.3s[Parallel(n_jobs=4)]: Done 600 out of 600 | elapsed:  9.0min finished

# %%
plot_error_grid(err, alphas, mus, maxerr=1)

# %%
task = get_task("uniform")def run(alpha, mu, method_class=td.TDC):    np.seterr(all="ignore")    m = method_class(alpha=alpha, beta=mu*alpha, phi=task.phi)    mean, std, raw = task.avg_error_traces([m], n_indep=3, n_samples=3000, criterion="RMSPBE", verbose=False)    val = np.mean(mean[0,-2000:])    #print "Evaluated alpha={}, mu={} to {}".format(alpha, mu, val)    return valalphas = np.power(10., np.linspace(-6, -1.5, 20))mus = np.power(2., np.linspace(-10, 15, 30))k = (delayed(run)(*x) for x in itertools.product(alphas, mus))res = Parallel(n_jobs=4, verbose=11)(k) err = np.array(res).reshape((len(alphas), len(mus)))
# Out:
# [Parallel(n_jobs=4)]: Done   1 out of 600 | elapsed:    3.7s remaining: 36.9min[Parallel(n_jobs=4)]: Done  52 out of 600 | elapsed:   49.6s remaining:  8.7min
# [Parallel(n_jobs=4)]: Done 107 out of 600 | elapsed:  1.7min remaining:  8.0min[Parallel(n_jobs=4)]: Done 162 out of 600 | elapsed:  2.7min remaining:  7.2min
# [Parallel(n_jobs=4)]: Done 217 out of 600 | elapsed:  3.5min remaining:  6.2min[Parallel(n_jobs=4)]: Done 272 out of 600 | elapsed:  4.4min remaining:  5.3min
# [Parallel(n_jobs=4)]: Done 327 out of 600 | elapsed:  5.3min remaining:  4.5min[Parallel(n_jobs=4)]: Done 382 out of 600 | elapsed:  6.2min remaining:  3.5min
# [Parallel(n_jobs=4)]: Done 437 out of 600 | elapsed:  7.0min remaining:  2.6min[Parallel(n_jobs=4)]: Done 492 out of 600 | elapsed:  7.9min remaining:  1.7min
# [Parallel(n_jobs=4)]: Done 547 out of 600 | elapsed:  8.7min remaining:   50.5s[Parallel(n_jobs=4)]: Done 600 out of 600 | elapsed:  9.5min finished

# %%
plot_error_grid(err, alphas, mus, maxerr=10)

# %%
task = get_task("uniform")def run(alpha, mu, method_class=td.TDC):    np.seterr(all="ignore")    m = method_class(alpha=alpha, beta=mu*alpha, phi=task.phi)    err = task.deterministic_error_traces([m], 100, criterion="RMSPBE")    val = np.mean(err)    #print "Evaluated alpha={}, mu={} to {}".format(alpha, mu, val)    return valalphas = np.power(10., np.linspace(-4, -0, 50))mus = np.power(2., np.linspace(-10, 15, 50))k = (delayed(run)(*x) for x in itertools.product(alphas, mus))res = Parallel(n_jobs=4, verbose=11)(k) err = np.array(res).reshape((len(alphas), len(mus)))
# Out:
# [Parallel(n_jobs=4)]: Done   1 out of 216 | elapsed:    0.0s remaining:    6.0s[Parallel(n_jobs=4)]: Done 222 out of 2500 | elapsed:    1.0s remaining:   10.5s
# [Parallel(n_jobs=4)]: Done 450 out of 2500 | elapsed:    2.0s remaining:    9.0s[Parallel(n_jobs=4)]: Done 678 out of 2500 | elapsed:    3.0s remaining:    8.0s
# [Parallel(n_jobs=4)]: Done 906 out of 2500 | elapsed:    4.0s remaining:    7.0s[Parallel(n_jobs=4)]: Done 1134 out of 2500 | elapsed:    4.9s remaining:    5.9s
# [Parallel(n_jobs=4)]: Done 1362 out of 2500 | elapsed:    5.8s remaining:    4.9s[Parallel(n_jobs=4)]: Done 1590 out of 2500 | elapsed:    6.8s remaining:    3.9s
# [Parallel(n_jobs=4)]: Done 1818 out of 2500 | elapsed:    7.8s remaining:    2.9s[Parallel(n_jobs=4)]: Done 2046 out of 2500 | elapsed:    8.7s remaining:    1.9s
# [Parallel(n_jobs=4)]: Done 2274 out of 2500 | elapsed:    9.7s remaining:    1.0s[Parallel(n_jobs=4)]: Done 2500 out of 2500 | elapsed:   10.6s finished

# %%
plot_error_grid(err, alphas, mus, maxerr=15)

# %% [markdown]
# ### Geri's TDCTDC but with a different position for sampling weights in the w-update: $$ w_{t+1} = w_t + \beta_t \rho_t (\delta_t - \phi^T_t w_t)\phi_t $$

# %%
task = get_task("uniform")def run(alpha, mu, method_class=td.GeriTDC):    np.seterr(all="ignore")    m = method_class(alpha=alpha, beta=mu*alpha, phi=task.phi)    mean, std, raw = task.avg_error_traces([m], n_indep=3, n_samples=3000, criterion="RMSPBE", verbose=False)    val = np.mean(mean[0,-200:])    #print "Evaluated alpha={}, mu={} to {}".format(alpha, mu, val)    return valalphas = np.power(10., np.linspace(-5, -1, 20))mus = np.power(2., np.linspace(-10, 15, 30))k = (delayed(run)(*x) for x in itertools.product(alphas, mus))res = Parallel(n_jobs=4, verbose=11)(k) err = np.array(res).reshape((len(alphas), len(mus)))
# Out:
# [Parallel(n_jobs=4)]: Done   1 out of 600 | elapsed:    3.6s remaining: 36.2min[Parallel(n_jobs=4)]: Done  52 out of 600 | elapsed:   48.4s remaining:  8.5min
# [Parallel(n_jobs=4)]: Done 107 out of 600 | elapsed:  1.6min remaining:  7.6min[Parallel(n_jobs=4)]: Done 162 out of 600 | elapsed:  2.5min remaining:  6.8min
# [Parallel(n_jobs=4)]: Done 217 out of 600 | elapsed:  3.3min remaining:  5.9min[Parallel(n_jobs=4)]: Done 272 out of 600 | elapsed:  4.2min remaining:  5.0min
# [Parallel(n_jobs=4)]: Done 327 out of 600 | elapsed:  5.1min remaining:  4.2min[Parallel(n_jobs=4)]: Done 382 out of 600 | elapsed:  6.2min remaining:  3.5min
# [Parallel(n_jobs=4)]: Done 437 out of 600 | elapsed:  7.2min remaining:  2.7min[Parallel(n_jobs=4)]: Done 492 out of 600 | elapsed:  8.3min remaining:  1.8min
# [Parallel(n_jobs=4)]: Done 547 out of 600 | elapsed:  9.3min remaining:   54.2s[Parallel(n_jobs=4)]: Done 600 out of 600 | elapsed: 10.4min finished

# %%
plot_error_grid(err, alphas, mus, maxerr=10)

# %% [markdown]
# ### GTD

# %%
task = get_task("target")def run(alpha, mu, method_class=td.GTD):    np.seterr(all="ignore")    m = method_class(alpha=alpha, beta=mu*alpha, phi=task.phi)    mean, std, raw = task.avg_error_traces([m], n_indep=10, n_samples=1000, criterion="RMSPBE", verbose=False)    val = np.mean(mean[0,-400:])    #print "Evaluated alpha={}, mu={} to {}".format(alpha, mu, val)    return valgtdalphas = np.power(10., np.linspace(-5, -1, 20))gtdmus = np.power(2., np.linspace(-13, 10, 30))k = (delayed(run)(*x) for x in itertools.product(gtdalphas, gtdmus))res = Parallel(n_jobs=4, verbose=11)(k) gtderr = np.array(res).reshape((len(gtdalphas), len(gtdmus)))
# Out:
# [Parallel(n_jobs=4)]: Done   1 out of 600 | elapsed:    3.8s remaining: 37.6min[Parallel(n_jobs=4)]: Done  52 out of 600 | elapsed:   48.2s remaining:  8.5min
# [Parallel(n_jobs=4)]: Done 107 out of 600 | elapsed:  1.7min remaining:  7.7min[Parallel(n_jobs=4)]: Done 162 out of 600 | elapsed:  2.5min remaining:  6.8min
# [Parallel(n_jobs=4)]: Done 217 out of 600 | elapsed:  3.4min remaining:  5.9min[Parallel(n_jobs=4)]: Done 272 out of 600 | elapsed:  4.2min remaining:  5.1min
# [Parallel(n_jobs=4)]: Done 327 out of 600 | elapsed:  5.1min remaining:  4.2min[Parallel(n_jobs=4)]: Done 382 out of 600 | elapsed:  5.9min remaining:  3.4min
# [Parallel(n_jobs=4)]: Done 437 out of 600 | elapsed:  6.8min remaining:  2.5min[Parallel(n_jobs=4)]: Done 492 out of 600 | elapsed:  7.6min remaining:  1.7min
# [Parallel(n_jobs=4)]: Done 547 out of 600 | elapsed:  8.4min remaining:   49.1s[Parallel(n_jobs=4)]: Done 600 out of 600 | elapsed:  9.2min finished

# %%
plot_error_grid(gtderr, gtdalphas, gtdmus, maxerr=1.)

# %%
task = get_task("uniform")def run(alpha, mu, method_class=td.GTD):    np.seterr(all="ignore")    m = method_class(alpha=alpha, beta=mu*alpha, phi=task.phi)    mean, std, raw = task.avg_error_traces([m], n_indep=10, n_samples=1000, criterion="RMSPBE", verbose=False)    val = np.mean(mean[0,-400:])    #print "Evaluated alpha={}, mu={} to {}".format(alpha, mu, val)    return valgtdalphas = np.power(10., np.linspace(-5, -1, 20))gtdmus = np.power(2., np.linspace(-13, 10, 30))k = (delayed(run)(*x) for x in itertools.product(gtdalphas, gtdmus))res = Parallel(n_jobs=4, verbose=11)(k) gtderr = np.array(res).reshape((len(gtdalphas), len(gtdmus)))
# Out:
# [Parallel(n_jobs=4)]: Done   1 out of 600 | elapsed:    4.0s remaining: 39.6min[Parallel(n_jobs=4)]: Done  52 out of 600 | elapsed:   52.1s remaining:  9.2min
# [Parallel(n_jobs=4)]: Done 107 out of 600 | elapsed:  1.7min remaining:  8.0min[Parallel(n_jobs=4)]: Done 162 out of 600 | elapsed:  2.6min remaining:  7.0min
# [Parallel(n_jobs=4)]: Done 217 out of 600 | elapsed:  3.5min remaining:  6.2min[Parallel(n_jobs=4)]: Done 272 out of 600 | elapsed:  4.4min remaining:  5.2min
# [Parallel(n_jobs=4)]: Done 327 out of 600 | elapsed:  5.2min remaining:  4.4min[Parallel(n_jobs=4)]: Done 382 out of 600 | elapsed:  6.1min remaining:  3.5min
# [Parallel(n_jobs=4)]: Done 437 out of 600 | elapsed:  7.0min remaining:  2.6min[Parallel(n_jobs=4)]: Done 492 out of 600 | elapsed:  7.8min remaining:  1.7min
# [Parallel(n_jobs=4)]: Done 547 out of 600 | elapsed:  8.6min remaining:   50.1s[Parallel(n_jobs=4)]: Done 600 out of 600 | elapsed:  9.4min finished

# %%
plot_error_grid(gtderr, gtdalphas, gtdmus, maxerr=10.)

# %% [markdown]
# ### Coordinate Descent search

# %%
from param import twiddlep = twiddle(run, p_start=[1, 4], dp = [1, 1], domain=[lambda x: x/100., lambda x: np.power(2,x)])print "Parameters: alpha={}, mu={}".format(alpha, mu)
